# %%
import tweepy
from textblob import TextBlob
import pandas as pd
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# Step 1 - Authenticate
consumer_key= 'CONSUMER_KEY_HERE'
consumer_secret= 'CONSUMER_SECRET_HERE'

access_token='ACCESS_TOKEN_HERE'
access_token_secret='ACCESS_TOKEN_SECRET_HERE'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
#Step 3 - Retrieve Tweets
public_tweets = api.search('India')

# %%
#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself

tweetsOnTrump = []
polarity = []
subjectivity = []
sentimentType = []

for tweet in public_tweets:
#     print(tweet.text)
    tweetsOnTrump.append(tweet.text)
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    
#     print(analysis.sentiment)
    polarity.append(analysis.sentiment.polarity)
    subjectivity.append(analysis.sentiment.subjectivity)
    if (analysis.sentiment.polarity > 0):
        sentimentType.append("positive")
    elif(analysis.sentiment.polarity < 0):
        sentimentType.append("negative") 
    elif(analysis.sentiment.polarity == 0):
        sentimentType.append("neutral")
        
       
#     print("")

# %%
print (tweetsOnTrump)
print (polarity)
print (subjectivity)
print (sentimentType)

# tweetsOnTrump = []
# polarity = []
# subjectivity = []


# df = pd.DataFrame(data={"tweetsOnTrump": tweetsOnTrump, "polarity": polarity, "subjectivity": subjectivity, "sentimentType": sentimentType})
# df.to_csv("twitter_trump_tweets.csv", sep=',',index=False)
# Out:
# ['RT @sxdoc: Donald Trump, “the racist”, comped, free of charge, Omarose Manigault’s $200,000 wedding at Trump Tower.  Meanwhile, she was tap…', "@flyachihuahua @greenfield64 And in actuality - no, he's not. \n\nRemoving the hate-Trump goggles reveals reality.", 'Top Trump adviser: US, Israel, Russia all want Iran out of Syria https://t.co/nJUOeQAuVE via @timesofisrael', 'RT @Frank_Schaeffer: The Republican Party is only in power and Trump is only “president”— not because of the Russians, but because of white…', "@theamandabatty @Ben_M_Berry @Twitter Such utter bullshit. I'm glad you got reinstated. I was locked out for saying… https://t.co/sfb0Kk43Qt", 'Omarosa was all for Donald Trump until he was against her so now she changes her tune in hopes of continuing her sp… https://t.co/vDmzWN0Wct', "RT @DearAuntCrabby: You wanna know what's better than @realDonaldTrump being impeached?\n\n#Trump being...\nThrown Out Of Office\nPut on Trial…", "RT @NBCNews: Rudy Giuliani threw more cold w
# ...

# %%
tweetsOnTrumpDataFrame = pd.read_csv('twitter_trump_tweets.csv')

tweetsOnTrumpDataFrame.head()
# Out:
#    polarity sentimentType  subjectivity  \
# 0  0.400000      positive      0.800000
# 1  0.000000       neutral      0.000000
# 2  0.500000      positive      0.500000
# 3  0.000000       neutral      1.000000
# 4  0.166667      positive      0.833333
#
#                                        tweetsOnTrump
# 0  RT @sxdoc: Donald Trump, “the racist”, comped,...
# 1  @flyachihuahua @greenfield64 And in actuality ...
# 2  Top Trump adviser: US, Israel, Russia all want...
# 3  RT @Frank_Schaeffer: The Republican Party is o...
# 4  @theamandabatty @Ben_M_Berry @Twitter Such utt...

# %% [markdown]
# # A function that takes input search tag and out put with a csv file an head of 10 row

# %%
def tweetSearch(topic):
    public_tweets = api.search(topic)
    
    tweetsOnTopic = []
    polarity = []
    subjectivity = []
    sentimentType = []
    
    for tweet in public_tweets:
        tweetsOnTopic.append(tweet.text)
        #Step 4 Perform Sentiment Analysis on Tweets
        analysis = TextBlob(tweet.text)

        polarity.append(analysis.sentiment.polarity)
        subjectivity.append(analysis.sentiment.subjectivity)
        if (analysis.sentiment.polarity > 0):
            sentimentType.append("positive")
        elif(analysis.sentiment.polarity < 0):
            sentimentType.append("negative") 
        elif(analysis.sentiment.polarity == 0):
            sentimentType.append("neutral")

        df = pd.DataFrame(data={"tweetsOn{}".format(topic): tweetsOnTopic, "polarity": polarity, "subjectivity": subjectivity, "sentimentType": sentimentType})
        df.to_csv("twitter_{}_tweets.csv".format(topic), sep=',',index=False)
        
    return df.head(10)

#Try With other names

# tweetSearch('Data Science')
tweetSearch('India')
# Out:
#    polarity sentimentType  subjectivity  \
# 0 -0.077778      negative      0.144444
# 1  0.500000      positive      0.500000
# 2  0.000000       neutral      0.550000
# 3  0.000000       neutral      0.000000
# 4  0.800000      positive      0.750000
# 5  0.500000      positive      0.500000
# 6 -0.737500      negative      0.900000
# 7  0.000000       neutral      0.000000
# 8 -0.050000      negative      0.600000
# 9 -0.025000      negative      0.775000
#
#                                        tweetsOnIndia
# 0  India crusing at 5 run per over in England aft...
# 1  RT @btsvotingteam: 🌎 TOP COUNTRIES tweeting \n...
# 2  RT @prasannavishy: Rafale deal, if embroiled i...
# 3  RT @NaijaFlyingDr: India made $108bn from soft...
# 4  RT @FarrukhNaeem: Great seeing #UAE leadership...
# 5  RT @btsvotingteam: 🌎 TOP COUNTRIES tweeting \n...
# 6  RT @AsYouNotWish: Dirty reality of India’s sec...
# 7  @Dhuandhaar @adgpi @IAF_MCC @PIB_India @Anupam...
# ...
